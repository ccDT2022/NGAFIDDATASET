# %% [markdown]
# <a href="https://colab.research.google.com/github/hyang0129/NGAFIDDATASET/blob/main/NGAFID_DATASET_TF_EXAMPLE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INSTALL PREREQ

# %%
# !git clone https://github.com/ccDT2022/NGAFIDDATASET.git

!(cd NGAFIDDATASET ; git checkout main; git reset --hard HEAD; git pull)
!(cd NGAFIDDATASET ; pip install -r requirements.txt -q)
# Out:
# Cloning into 'NGAFIDDATASET'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 47 (delta 18), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (47/47), 496.50 KiB | 7.41 MiB/s, done.
# Resolving deltas: 100% (18/18), done.
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# HEAD is now at 32262a3 Add files via upload
# Already up to date.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.9/91.9 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 33.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.8/269.8 kB 30.6 MB/s eta 0:00:00

# %% [markdown]
# # IMPORT DEPENDENCIES

# %%
# 1. 导入必要的系统库
import sys
import importlib

# 2. 打补丁：将 importlib 伪装成 Python 3.12 中已经被移除的 imp 模块
sys.modules['imp'] = importlib

# 3. 补充原代码逻辑：将下载好的数据集项目路径添加到系统环境变量中
sys.path.append('/content/NGAFIDDATASET')

# 4. 此时系统里已经有了一个“假”的 imp，可以安全地加载 autoreload 扩展了
# %load_ext autoreload

# %%
from tqdm.autonotebook import tqdm
# Out:
# /tmp/ipykernel_19112/527081995.py:1: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
# %autoreload
from ngafiddataset.dataset.dataset import NGAFID_Dataset_Manager
from ngafiddataset.dataset.utils import to_dict_of_list
from ngafiddataset.utils import connect_to_tpu
import pandas as pd


strategy = connect_to_tpu()
# Out:
# /content/NGAFIDDATASET/ngafiddataset/dataset/dataset.py:55: SyntaxWarning: invalid escape sequence '\o'
#   logger.info('Downloading and extracting Parquet Files to %s\one_parq.  Please open them using dask dataframes' % destination)
# No TPU Available
# REPLICAS:  1

# %% [markdown]
# # DEFINE MODEL FN

# %%
import tensorflow as tf

tfk = tf.keras
tfkl = tf.keras.layers

class Classifier_INCEPTION:
    def __init__(
        self,
        input_shape,
        nb_classes,
        build=True,
        batch_size=64,
        nb_filters=32,
        use_residual=True,
        use_bottleneck=True,
        depth=6,
        kernel_size=41,
        nb_epochs=1500,
        two_output = False,
        mode = None
    ):

        self.nb_filters = nb_filters
        self.use_residual = use_residual
        self.use_bottleneck = use_bottleneck
        self.depth = depth
        self.kernel_size = kernel_size - 1
        self.callbacks = None
        self.batch_size = batch_size
        self.bottleneck_size = 32
        self.nb_epochs = nb_epochs
        self.two_output = two_output
        self.mode = mode

        if build is True:
            self.model = self.build_model(input_shape, nb_classes)

    def _inception_module(self, input_tensor, stride=1, activation="linear"):

        if self.use_bottleneck and int(input_tensor.shape[-1]) > 1:
            input_inception = tf.keras.layers.Conv1D(
                filters=self.bottleneck_size, kernel_size=1, padding="same", activation=activation, use_bias=False
            )(input_tensor)
        else:
            input_inception = input_tensor

        # kernel_size_s = [3, 5, 8, 11, 17]
        kernel_size_s = [self.kernel_size // (2 ** i) for i in range(3)]

        conv_list = []

        for i in range(len(kernel_size_s)):
            conv_list.append(
                tf.keras.layers.Conv1D(
                    filters=self.nb_filters,
                    kernel_size=kernel_size_s[i],
                    strides=stride,
                    padding="same",
                    activation=activation,
                    use_bias=False,
                )(input_inception)
            )

        max_pool_1 = tf.keras.layers.MaxPool1D(pool_size=3, strides=stride, padding="same")(input_tensor)

        conv_6 = tf.keras.layers.Conv1D(
            filters=self.nb_filters, kernel_size=1, padding="same", activation=activation, use_bias=False
        )(max_pool_1)

        conv_list.append(conv_6)

        x = tf.keras.layers.Concatenate(axis=2)(conv_list)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Activation(activation="relu")(x)
        return x

    def _shortcut_layer(self, input_tensor, out_tensor):
        shortcut_y = tf.keras.layers.Conv1D(
            filters=int(out_tensor.shape[-1]), kernel_size=1, padding="same", use_bias=False
        )(input_tensor)
        shortcut_y = tf.keras.layers.BatchNormalization()(shortcut_y)

        x = tf.keras.layers.Add()([shortcut_y, out_tensor])
        x = tf.keras.layers.Activation("relu")(x)
        return x

    def build_model(self, input_shape, nb_classes):
        input_layer = tf.keras.layers.Input(input_shape, name = 'data')

        x = input_layer
        input_res = input_layer

        for d in range(self.depth):

            x = self._inception_module(x)

            if self.use_residual and d % 3 == 2:
                x = self._shortcut_layer(input_res, x)
                input_res = x

        gap_layer = tf.keras.layers.GlobalAveragePooling1D()(x)


        outputs = []

        outputs.append(tf.keras.layers.Dense(nb_classes, activation="softmax", name='target_class')(gap_layer))

        if self.two_output:
            outputs.append(tf.keras.layers.Dense(1, activation="sigmoid", name='before_after')(gap_layer))


        if self.mode == 'before_after':
            outputs = []
            outputs.append(tf.keras.layers.Dense(1, activation="sigmoid", name='before_after')(gap_layer))

        model = tf.keras.models.Model(inputs=input_layer, outputs=outputs)

        return model

    def get_kernel_model(self):
        '''
        Get a model whose output is just the global average pooling layer.

        Returns:

        '''

        return tf.keras.Model(self.model.layers[0].input, self.model.layers[-2].output)

# %%
def point_wise_feed_forward_network(d_model, dff):
  return tf.keras.Sequential([
      tf.keras.layers.Dense(dff, activation='relu'),  # (batch_size, seq_len, dff)
      tf.keras.layers.Dense(d_model)  # (batch_size, seq_len, d_model)
  ])

def scaled_dot_product_attention(q, k, v, mask):
  """Calculate the attention weights.
  q, k, v must have matching leading dimensions.
  k, v must have matching penultimate dimension, i.e.: seq_len_k = seq_len_v.
  The mask has different shapes depending on its type(padding or look ahead)
  but it must be broadcastable for addition.

  Args:
    q: query shape == (..., seq_len_q, depth)
    k: key shape == (..., seq_len_k, depth)
    v: value shape == (..., seq_len_v, depth_v)
    mask: Float tensor with shape broadcastable
          to (..., seq_len_q, seq_len_k). Defaults to None.

  Returns:
    output, attention_weights
  """

  matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)

  # scale matmul_qk
  dk = tf.cast(tf.shape(k)[-1], tf.float32)
  scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

  # add the mask to the scaled tensor.
  if mask is not None:
    scaled_attention_logits += (mask * -1e9)

  # softmax is normalized on the last axis (seq_len_k) so that the scores
  # add up to 1.
  attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

  output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

  return output, attention_weights

class MultiHeadAttention(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads):
    super(MultiHeadAttention, self).__init__()
    self.num_heads = num_heads
    self.d_model = d_model

    assert d_model % self.num_heads == 0

    self.depth = d_model // self.num_heads

    self.wq = tf.keras.layers.Dense(d_model)
    self.wk = tf.keras.layers.Dense(d_model)
    self.wv = tf.keras.layers.Dense(d_model)

    self.dense = tf.keras.layers.Dense(d_model)

  def split_heads(self, x, batch_size):
    """Split the last dimension into (num_heads, depth).
    Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
    """
    x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(x, perm=[0, 2, 1, 3])

  def call(self, v, k, q, mask):
    batch_size = tf.shape(q)[0]

    q = self.wq(q)  # (batch_size, seq_len, d_model)
    k = self.wk(k)  # (batch_size, seq_len, d_model)
    v = self.wv(v)  # (batch_size, seq_len, d_model)

    q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
    k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
    v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)

    # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
    # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
    scaled_attention, attention_weights = scaled_dot_product_attention(
        q, k, v, mask)

    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)

    concat_attention = tf.reshape(scaled_attention,
                                  (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)

    output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)

    return output, attention_weights

class EncoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(EncoderLayer, self).__init__()

    self.mha = MultiHeadAttention(d_model, num_heads)
    self.ffn = point_wise_feed_forward_network(d_model, dff)

    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)

  #def call(self, x, training, mask = None):
  def call(self, x, training=None, mask=None):

    attn_output, self.attention_values = self.mha(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
    attn_output = self.dropout1(attn_output, training=training)
    out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)

    ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
    ffn_output = self.dropout2(ffn_output, training=training)
    out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)

    return out2

def get_angles(pos, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
    return pos * angle_rates

def positional_encoding(position, d_model):
    angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                            np.arange(d_model)[np.newaxis, :],
                            d_model)

    # apply sin to even indices in the array; 2i
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])

    # apply cos to odd indices in the array; 2i+1
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

    pos_encoding = angle_rads[np.newaxis, ...]

    return tf.cast(pos_encoding, dtype=tf.float32)

class PositionalEncoding(tf.keras.layers.Layer):

    def __init__(self, maximum_position_encoding = 1000):
        super(PositionalEncoding, self).__init__()

        self.pos_encoding = positional_encoding(maximum_position_encoding,
                                        512)

    def call(self, x):

        seq_len = tf.shape(x)[1]
        x += self.pos_encoding[:, :seq_len, :]

        return x

def get_mhsa_model(nbclass = 2, SHAPE = (4096, 23), mode = 'before_after'):
    # I realize that I did not include a positional embedding, but its too late now. Maybe a future paper could address this?
    d = 512
    ff = 1024
    model =  tfk.Sequential([tf.keras.Input(shape = SHAPE),
                                            tfkl.Conv1D(128, 7, strides = 1, padding='same', activation='relu'),
                                            # tfkl.BatchNormalization(),
                                            tfkl.Conv1D(128, 7, strides = 2, padding='same', activation='relu'),
                                            # tfkl.BatchNormalization(),
                                            tfkl.Conv1D(256, 7, strides = 1, padding='same', activation='relu'),
                                            # tfkl.BatchNormalization(),
                                            tfkl.Conv1D(256, 7, strides = 2, padding='same', activation='relu'),
                                            # tfkl.BatchNormalization(),
                                            # tfkl.Conv1D(512, 7, strides = 1, padding='same', activation='relu'),
                                            tfkl.Conv1D(512, 7, strides = 2, padding='same', activation='relu'),
                                            # tfkl.Conv1D(768, 7, strides = 1, padding='same', activation='relu'),
                                            # tfkl.BatchNormalization(),
                                            EncoderLayer(d_model=d, num_heads=8, dff=ff),
                                            EncoderLayer(d_model=d, num_heads=8, dff=ff),
                                            EncoderLayer(d_model=d, num_heads=8, dff=ff),
                                            EncoderLayer(d_model=d, num_heads=8, dff=ff),

                                            tf.keras.layers.GlobalAveragePooling1D(),
                                            # tfkl.Dense(nbclass, activation='softmax'),
    ])


    input = tf.keras.Input(shape = SHAPE, name = 'data')

    x = model(input)

    output = []
    if mode == 'before_after':
        output =  tfkl.Dense(1, activation='sigmoid', name = 'before_after')(x)
    elif mode == 'both':
        output.append(tf.keras.layers.Dense(nbclass, activation="softmax", name='target_class')(x))
        output.append(tfkl.Dense(1, activation='sigmoid', name = 'before_after')(x))
    elif mode == 'classes':
        output.append(tf.keras.layers.Dense(nbclass, activation="softmax", name='target_class')(x))

    fun_model = tf.keras.Model(input, output)

    return fun_model

def get_mhsa_model_pe():
    # I realize that I did not include a positional embedding, but its too late now. Maybe a future paper could address this?

    model =  tfk.Sequential([tf.keras.Input(shape = SHAPE),
                                            tfkl.Conv1D(128, 7, strides = 1, padding='same', activation='relu'),
                                            tfkl.BatchNormalization(),
                                            tfkl.Conv1D(128, 7, strides = 2, padding='same', activation='relu'),
                                            tfkl.BatchNormalization(),
                                            tfkl.Conv1D(256, 3, strides = 1, padding='same', activation='relu'),
                                            tfkl.BatchNormalization(),
                                            tfkl.Conv1D(256, 7, strides = 2, padding='same', activation='relu'),
                                            tfkl.BatchNormalization(),
                                            tfkl.Conv1D(512, 7, strides = 2, padding='same', activation='relu'),
                                            tfkl.BatchNormalization(),
                                            # tfkl.Conv1D(512, 7, strides = 2, padding='same', activation='relu'),
                                            # tfkl.Conv1D(512, 7, strides = 2, padding='same', activation='relu'),
                                            PositionalEncoding(),
                                            EncoderLayer(d_model=512, num_heads=8, dff=512),
                                            EncoderLayer(d_model=512, num_heads=8, dff=512),
                                            EncoderLayer(d_model=512, num_heads=8, dff=512),
                                            EncoderLayer(d_model=512, num_heads=8, dff=512),
                                            # tfkl.Lambda(lambda x : x[:, 0, :]),
                                            tf.keras.layers.GlobalAveragePooling1D(),
                                            tfkl.Dense(1, activation='sigmoid'),
    ])

    return model


model = get_mhsa_model(mode = 'both')
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ data (InputLayer)   │ (None, 4096, 23)  │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_4        │ (None, 512)       │ 10,153,344 │ data[0][0]        │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ target_class        │ (None, 2)         │      1,026 │ sequential_4[0][… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ before_after        │ (None, 1)         │        513 │ sequential_4[0][… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 10,154,883 (38.74 MB)
#  Trainable params: 10,154,883 (38.74 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # SETUP DATA

# %%
# 1. 删除刚才下载失败的“伪装网页”文件
# !rm -f /content/2days.tar.gz
# !rm -rf /content/2days

# 2. 使用正确的直链接口，强制下载真实的 2days 数据集
# !gdown "https://drive.google.com/uc?id=1OlvdT5xk9-mvFnlhfXYydxRnEUtVe-yH" -O /content/2days.tar.gz

# 3. 将下载好的压缩包解压到当前目录
# !tar -xzf /content/2days.tar.gz -C /content/

print("✅ 2days 数据集下载并解压完成！")

# 4. 继续运行原本的数据加载逻辑（关键：加上 extract=False 防止它再次尝试解压）
from ngafiddataset.dataset.dataset import NGAFID_Dataset_Manager
import pandas as pd

dm = NGAFID_Dataset_Manager('2days', extract=False)
df = pd.read_csv('/content/2days/flight_header.csv')

# 构建数据字典 (注意 TF 版本的例子这里用的是 numpy=False)
dm.data_dict = dm.construct_data_dictionary(numpy=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1OlvdT5xk9-mvFnlhfXYydxRnEUtVe-yH
# From (redirected): https://drive.google.com/uc?id=1OlvdT5xk9-mvFnlhfXYydxRnEUtVe-yH&confirm=t&uuid=42197cf4-6497-45e5-b37d-5d6490f42981
# To: /content/2days.tar.gz
# 100% 1.13G/1.13G [00:12<00:00, 92.0MB/s]
# ✅ 2days 数据集下载并解压完成！
#   0%|          | 0/11446 [00:00<?, ?it/s]

# %%
number_classes = len(dm.flight_header_df['class'].unique())
number_classes

number_hierarchies = len(dm.flight_header_df['hclass'].unique())
number_hierarchies
# Out:
# 5

# %% [markdown]
# # DEFINE TASK

# %%
mode = 'before_after' #开启维护前vs维护后的二分类任务
# mode = 'hierarchy_basic'
#mode = 'both'  #同时输出分类结果（target_class）和二分类结果（before_after）。
# mode = 'classes' #多分类任务
#Baseline 复现使用 mode = 'before_after'，完成维护事件二分类检测
#改进方面使用mode = 'both'（多任务学习），通过引入故障类型的标签作为辅助任务，模型能够学习到更细致的故障特征，从而反过来提升二分类（维护前/后）的判断准确度。

# DETERMINE MODEL STRUCTURE BASED ON OUTPUTS
two_output = False
if mode == 'before_after':
    nb_classes = 1
elif mode == 'hierarchy_basic':
    nb_classes = number_hierarchies + 1
    two_output = True
elif mode == 'both':
    two_output = True
    nb_classes = number_classes+1
else:
    nb_classes = number_classes+1

# %% [markdown]
# # TRAIN MODEL

# %%
class Saver(tf.keras.callbacks.Callback):

    def __init__(self, model_name):
        super().__init__()
        self.model_name = model_name
        # self.bucket = bucket
        # self.fs = gcsfs.GCSFileSystem(project='tpu-44747', token = 'gckey.json')
        self.start = 5
        self.best = 0

    def on_epoch_end(self, epoch, logs=None):
        if epoch > self.start:
            pass

        metric = 'val_loss'

        try:
            if logs.get(metric) >= 0.85 and logs.get(metric) > self.best:
                print('saving good model')
                lpath = self.model_name + '.h5'
                self.model.save(lpath, include_optimizer=False)
                self.best = logs.get(metric)
        except Exception as E:
            print('encountered some error in model saving process')
            print(E)
            pass

# %%
import numpy as np
import pandas as pd
from tqdm.autonotebook import tqdm
#model_name = 'ITIME_BOTH'
model_name = 'CONVMHSA_BOTH'
save_path = ''
all_fold_accuracies = [] # 用于存储每折的最佳准确率

flight_res = []


for fold in tqdm(range(5)):

    save_filename = save_path + '%s_%i' % (model_name, fold)

    #减小 batch_size，避免发生OOM
    #train_ds = dm.get_tf_dataset(fold = fold, training = True, shuffle = 1000, repeat = True, mode = mode, batch_size = 128)
    train_ds = dm.get_tf_dataset(fold = fold, training = True, shuffle = 1000, repeat = True, mode = mode, batch_size = 32)
    #test_ds = dm.get_tf_dataset(fold = fold, training  = False, shuffle = False, repeat = False, mode = mode, batch_size = 128)
    test_ds = dm.get_tf_dataset(fold = fold, training  = False, shuffle = False, repeat = False, mode = mode, batch_size = 32)



    with strategy.scope():
        #在训练中使用 InceptionTime 模型，默认为InceptionTime
        #model = Classifier_INCEPTION(input_shape = (4096, 23), nb_classes=nb_classes, two_output = two_output ).model
        #lr = 1e-4
        #在训练中使用 ConvMHSA 模型
        model = get_mhsa_model(nbclass=nb_classes, mode = mode)
        lr = 3e-5

        if two_output:

            model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=lr),
                        metrics =
                                    {'target_class' : [tf.keras.metrics.SparseCategoricalAccuracy(name = 'multi_acc')],
                                    'before_after' : [tf.keras.metrics.BinaryAccuracy(name = 'single_acc')],
                                    }

                        ,
                        loss = {'target_class' : tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False, name = 'multi_loss'),
                                'before_after' : tf.keras.losses.BinaryCrossentropy(from_logits=False, name = 'single_loss')}
            )


        elif mode == 'before_after':

            model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=lr),
                        metrics = [
                                    tf.keras.metrics.BinaryAccuracy()
                        ],
                        loss = tf.keras.losses.BinaryCrossentropy(from_logits=False))


        elif mode == 'classes':

            model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=lr),
                        metrics = [
                                    tf.keras.metrics.SparseCategoricalAccuracy(name = 'multi_acc')
                        ],
                        loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False))

        else:
            raise


        callbacks = [
                tf.keras.callbacks.ModelCheckpoint(
                    filepath="best.weights.h5",
                    save_best_only=True,  # Only save a model if `val_loss` has improved.
                    monitor="val_loss",
                    verbose=1,
                    save_weights_only=True
                ),
                # 碍于电脑性能，加入下面这行自动早停代码，patience=15，表示如果15轮没进步就提前结束这200轮的训练
                tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

            ]


        history = model.fit(
            train_ds,
            steps_per_epoch = 100,
            #在epochs = 85发生卡顿，原来为200，现改为20.因为5轮为100
            epochs = 30,
            validation_data = test_ds,
            callbacks = callbacks,
            verbose = True,

        )

        history = pd.DataFrame(history.history)
        history['epoch'] = history.index
        history['model'] = model_name
        history.to_csv(save_filename)

        #model.load_weights('best.h5')
        model.load_weights('best.weights.h5')
        # --- 新增：评估并记录本折准确率 ---
        eval_results = model.evaluate(test_ds, verbose=0)

        # 提取准确率：根据 compile 时的定义，通常索引 1 是准确率
        # 如果是 multi-output (both)，single_acc 通常在最后
        fold_acc = eval_results[-1] if two_output or mode == 'both' else eval_results[1]
        all_fold_accuracies.append(fold_acc)
        print(f"Fold {fold} Best Val Accuracy: {fold_acc:.4f}")

        '''
        flights_before_acc = {}

        for day in range(5):


            indices = list(dm.flight_header_df[ (dm.flight_header_df['number_flights_before'] == day) & (dm.flight_header_df.before_after == 1) & (dm.flight_header_df.fold == fold) & (dm.flight_header_df.label == 'intake gasket leak/damage')].index)
            print(len(indices))
            ds = tf.data.Dataset.from_tensor_slices(to_dict_of_list([example for example in dm.data_dict if example['id'] in indices]))

            ds = dm.get_tf_dataset(ds = ds , fold = 0, training  = False, shuffle = False, repeat = False, mode = mode, batch_size = 2)

            res = model.evaluate(ds)

            flights_before_acc[day] = res[-1]

        flight_res.append(flights_before_acc)
        '''
        # --- 新增：最终报告打印 ---
if all_fold_accuracies:
    mean_acc = np.mean(all_fold_accuracies)
    std_acc = np.std(all_fold_accuracies)

    print("\n" + "="*40)
    print("      最终交叉验证报告 (CV REPORT)      ")
    print("="*40)
    for i, acc in enumerate(all_fold_accuracies):
        print(f"Fold {i}: 准确率 = {acc:.4f}")
    print("-" * 40)
    print(f"平均准确率 (Mean): {mean_acc:.4f}")
    print(f"标准差 (Std Dev):  {std_acc:.4f}")
    print(f"综合表现: {mean_acc:.4f} ± {std_acc:.4f}")
    print("="*40)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 1/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 526ms/step - binary_accuracy: 0.4885 - loss: 0.8273
# Epoch 1: val_loss improved from None to 0.69958, saving model to best.weights.h5
#
# Epoch 1: finished saving model to best.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 100s 684ms/step - binary_accuracy: 0.4966 - loss: 0.7484 - val_binary_accuracy: 0.5110 - val_loss: 0.6996
# Epoch 2/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 527ms/step - binary_accuracy: 0.5021 - loss: 0.7000
# Epoch 2: val_loss did not improve from 0.69958
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 640ms/step - binary_accuracy: 0.5128 - loss: 0.6987 - val_binary_accuracy: 0.5097 - val_loss: 0.7274
# Epoch 3/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - binary_accuracy: 0.5080 - loss: 0.7013
# Epoch 3: val_loss did not improve from 0.69958
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 642ms/step - binary_accuracy: 0.4981 - loss: 0.7074 - val_binary_accuracy: 0.5097 - val_loss: 0.7630
# Epoch 4/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - binary_accuracy: 0.5198 - loss: 0.7099
# Epoch 4: val_loss did not improve from 0.69958
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 642ms/step - binary_accuracy: 0.5141 - loss: 0.7044 - val_binary_accuracy: 0.5097 - val_loss: 0.7036
# Epoch 5/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - binary_accuracy: 0.5136 - loss: 0.6984
# Epoch 5: val_loss did not improve from 0.69958
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 640ms/step - binary_accuracy: 0.5084 - loss: 0.7017 - val_binary_accuracy: 0.5084 - val_loss: 0.7008
# Epoch 6/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5020 - loss: 0.6964
# Epoch 6: val_loss improved from 0.69958 to 0.69260, saving model to best.weights.h5
#
# Epoch 6: finished saving model to best.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 648ms/step - binary_accuracy: 0.4816 - loss: 0.6983 - val_binary_accuracy: 0.5066 - val_loss: 0.6926
# Epoch 7/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - binary_accuracy: 0.5022 - loss: 0.7004
# Epoch 7: val_loss did not improve from 0.69260
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 646ms/step - binary_accuracy: 0.5181 - loss: 0.6988 - val_binary_accuracy: 0.4903 - val_loss: 0.7347
# Epoch 8/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5217 - loss: 0.7004
# Epoch 8: val_loss did not improve from 0.69260
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 644ms/step - binary_accuracy: 0.5175 - loss: 0.6975 - val_binary_accuracy: 0.4930 - val_loss: 0.6988
# Epoch 9/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - binary_accuracy: 0.5046 - loss: 0.6979
# Epoch 9: val_loss did not improve from 0.69260
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 640ms/step - binary_accuracy: 0.5088 - loss: 0.6978 - val_binary_accuracy: 0.5079 - val_loss: 0.6936
# Epoch 10/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5184 - loss: 0.6968
# Epoch 10: val_loss did not improve from 0.69260
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 644ms/step - binary_accuracy: 0.5216 - loss: 0.6990 - val_binary_accuracy: 0.5097 - val_loss: 0.7360
# Epoch 11/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - binary_accuracy: 0.4830 - loss: 0.7107
# Epoch 11: val_loss did not improve from 0.69260
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 641ms/step - binary_accuracy: 0.4906 - loss: 0.7032 - val_binary_accuracy: 0.5092 - val_loss: 0.6993
# Epoch 12/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5071 - loss: 0.6978
# Epoch 12: val_loss did not improve from 0.69260
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 643ms/step - binary_accuracy: 0.5050 - loss: 0.6983 - val_binary_accuracy: 0.5097 - val_loss: 0.7016
# Epoch 13/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - binary_accuracy: 0.5316 - loss: 0.6931
# Epoch 13: val_loss improved from 0.69260 to 0.69243, saving model to best.weights.h5
#
# Epoch 13: finished saving model to best.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 648ms/step - binary_accuracy: 0.5325 - loss: 0.6933 - val_binary_accuracy: 0.5207 - val_loss: 0.6924
# Epoch 14/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.4875 - loss: 0.7010
# Epoch 14: val_loss did not improve from 0.69243
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 644ms/step - binary_accuracy: 0.4900 - loss: 0.7027 - val_binary_accuracy: 0.5097 - val_loss: 0.6935
# Epoch 15/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - binary_accuracy: 0.5156 - loss: 0.6940
# Epoch 15: val_loss did not improve from 0.69243
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 642ms/step - binary_accuracy: 0.5241 - loss: 0.6926 - val_binary_accuracy: 0.5097 - val_loss: 0.7413
# Epoch 16/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - binary_accuracy: 0.5259 - loss: 0.6969
# Epoch 16: val_loss did not improve from 0.69243
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 643ms/step - binary_accuracy: 0.5194 - loss: 0.6956 - val_binary_accuracy: 0.5150 - val_loss: 0.6935
# Epoch 17/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5221 - loss: 0.7009
# Epoch 17: val_loss did not improve from 0.69243
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 643ms/step - binary_accuracy: 0.5081 - loss: 0.7013 - val_binary_accuracy: 0.5202 - val_loss: 0.6925
# Epoch 18/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5117 - loss: 0.6951
# Epoch 18: val_loss improved from 0.69243 to 0.69237, saving model to best.weights.h5
#
# Epoch 18: finished saving model to best.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 648ms/step - binary_accuracy: 0.5169 - loss: 0.6940 - val_binary_accuracy: 0.5189 - val_loss: 0.6924
# Epoch 19/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - binary_accuracy: 0.5400 - loss: 0.6909
# Epoch 19: val_loss did not improve from 0.69237
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 643ms/step - binary_accuracy: 0.5197 - loss: 0.6940 - val_binary_accuracy: 0.5246 - val_loss: 0.6927
# Epoch 20/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - binary_accuracy: 0.5258 - loss: 0.6959
# Epoch 20: val_loss did not improve from 0.69237
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 643ms/step - binary_accuracy: 0.5209 - loss: 0.6954 - val_binary_accuracy: 0.5401 - val_loss: 0.6957
# Epoch 21/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - binary_accuracy: 0.5413 - loss: 0.6904
# Epoch 21: val_loss did not improve from 0.69237
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 641ms/step - binary_accuracy: 0.5325 - loss: 0.6918 - val_binary_accuracy: 0.4903 - val_loss: 0.7308
# Epoch 22/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - binary_accuracy: 0.4811 - loss: 0.7192
# Epoch 22: val_loss did not improve from 0.69237
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 641ms/step - binary_accuracy: 0.4903 - loss: 0.7081 - val_binary_accuracy: 0.4912 - val_loss: 0.7014
# Epoch 23/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5114 - loss: 0.6943
# Epoch 23: val_loss did not improve from 0.69237
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 643ms/step - binary_accuracy: 0.5034 - loss: 0.6988 - val_binary_accuracy: 0.4903 - val_loss: 0.7184
# Epoch 24/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - binary_accuracy: 0.5167 - loss: 0.6947
# Epoch 24: val_loss did not improve from 0.69237
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 642ms/step - binary_accuracy: 0.5362 - loss: 0.6913 - val_binary_accuracy: 0.5066 - val_loss: 0.7212
# Epoch 25/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - binary_accuracy: 0.4957 - loss: 0.7038
# Epoch 25: val_loss improved from 0.69237 to 0.69227, saving model to best.weights.h5
#
# Epoch 25: finished saving model to best.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 645ms/step - binary_accuracy: 0.4988 - loss: 0.6994 - val_binary_accuracy: 0.5238 - val_loss: 0.6923
# Epoch 26/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - binary_accuracy: 0.5061 - loss: 0.6958
# Epoch 26: val_loss did not improve from 0.69227
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 642ms/step - binary_accuracy: 0.5091 - loss: 0.6960 - val_binary_accuracy: 0.4903 - val_loss: 0.7098
# Epoch 27/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - binary_accuracy: 0.4941 - loss: 0.7012
# Epoch 27: val_loss did not improve from 0.69227
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 642ms/step - binary_accuracy: 0.5191 - loss: 0.6945 - val_binary_accuracy: 0.5150 - val_loss: 0.6965
# Epoch 28/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 527ms/step - binary_accuracy: 0.5031 - loss: 0.6989
# Epoch 28: val_loss did not improve from 0.69227
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 640ms/step - binary_accuracy: 0.5069 - loss: 0.6991 - val_binary_accuracy: 0.5110 - val_loss: 0.6925
# Epoch 29/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - binary_accuracy: 0.5041 - loss: 0.6961
# Epoch 29: val_loss did not improve from 0.69227
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 643ms/step - binary_accuracy: 0.5047 - loss: 0.6952 - val_binary_accuracy: 0.4982 - val_loss: 0.6935
# Epoch 30/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 527ms/step - binary_accuracy: 0.5469 - loss: 0.6898
# Epoch 30: val_loss did not improve from 0.69227
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 640ms/step - binary_accuracy: 0.5378 - loss: 0.6918 - val_binary_accuracy: 0.5088 - val_loss: 0.7131
# Fold 0 Best Val Accuracy: 0.5238
# Epoch 1/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - binary_accuracy: 0.4980 - loss: 0.7793
# Epoch 1: val_loss improved from None to 0.69964, saving model to best.weights.h5
#
# Epoch 1: finished saving model to best.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 90s 680ms/step - binary_accuracy: 0.5106 - loss: 0.7252 - val_binary_accuracy: 0.4921 - val_loss: 0.6996
# Epoch 2/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - binary_accuracy: 0.5015 - loss: 0.7055
# Epoch 2: val_loss did not improve from 0.69964
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 644ms/step - binary_accuracy: 0.5072 - loss: 0.7059 - val_binary_accuracy: 0.4921 - val_loss: 0.7588
# Epoch 3/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - binary_accuracy: 0.4856 - loss: 0.7293
# Epoch 3: val_loss did not improve from 0.69964
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 647ms/step - binary_accuracy: 0.4934 - loss: 0.7153 - val_binary_accuracy: 0.4921 - val_loss: 0.7013
# Epoch 4/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - binary_accuracy: 0.5054 - loss: 0.6959
# Epoch 4: val_loss did not improve from 0.69964
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 643ms/step - binary_accuracy: 0.5028 - loss: 0.6970 - val_binary_accuracy: 0.5088 - val_loss: 0.7051
# Epoch 5/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - binary_accuracy: 0.4927 - loss: 0.7012
# Epoch 5: val_loss improved from 0.69964 to 0.69278, saving model to best.weights.h5
#
# Epoch 5: finished saving model to best.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 650ms/step - binary_accuracy: 0.4966 - loss: 0.6993 - val_binary_accuracy: 0.5088 - val_loss: 0.6928
# Epoch 6/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - binary_accuracy: 0.4909 - loss: 0.7029
# Epoch 6: val_loss improved from 0.69278 to 0.69140, saving model to best.weights.h5
#
# Epoch 6: finished saving model to best.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 649ms/step - binary_accuracy: 0.5044 - loss: 0.6999 - val_binary_accuracy: 0.5233 - val_loss: 0.6914
# Epoch 7/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - binary_accuracy: 0.5157 - loss: 0.6971
# Epoch 7: val_loss did not improve from 0.69140
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 646ms/step - binary_accuracy: 0.5131 - loss: 0.7001 - val_binary_accuracy: 0.5084 - val_loss: 0.6928
# Epoch 8/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5156 - loss: 0.6950
# Epoch 8: val_loss did not improve from 0.69140
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 643ms/step - binary_accuracy: 0.5122 - loss: 0.6969 - val_binary_accuracy: 0.5040 - val_loss: 0.6939
# Epoch 9/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - binary_accuracy: 0.5029 - loss: 0.6960
# Epoch 9: val_loss did not improve from 0.69140
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 645ms/step - binary_accuracy: 0.5031 - loss: 0.6972 - val_binary_accuracy: 0.4921 - val_loss: 0.6990
# Epoch 10/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - binary_accuracy: 0.5219 - loss: 0.6976
# Epoch 10: val_loss did not improve from 0.69140
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 646ms/step - binary_accuracy: 0.5172 - loss: 0.6970 - val_binary_accuracy: 0.5022 - val_loss: 0.6940
# Epoch 11/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - binary_accuracy: 0.5073 - loss: 0.7063
# Epoch 11: val_loss did not improve from 0.69140
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 641ms/step - binary_accuracy: 0.5075 - loss: 0.7093 - val_binary_accuracy: 0.5295 - val_loss: 0.6923
# Epoch 12/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - binary_accuracy: 0.5243 - loss: 0.6958
# Epoch 12: val_loss did not improve from 0.69140
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 647ms/step - binary_accuracy: 0.5169 - loss: 0.6964 - val_binary_accuracy: 0.5101 - val_loss: 0.6965
# Epoch 13/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5008 - loss: 0.6995
# Epoch 13: val_loss did not improve from 0.69140
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 644ms/step - binary_accuracy: 0.5169 - loss: 0.6977 - val_binary_accuracy: 0.4921 - val_loss: 0.7035
# Epoch 14/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - binary_accuracy: 0.5174 - loss: 0.6953
# Epoch 14: val_loss did not improve from 0.69140
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 645ms/step - binary_accuracy: 0.5069 - loss: 0.6962 - val_binary_accuracy: 0.5145 - val_loss: 0.6922
# Epoch 15/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - binary_accuracy: 0.5177 - loss: 0.6939
# Epoch 15: val_loss did not improve from 0.69140
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 647ms/step - binary_accuracy: 0.5141 - loss: 0.6944 - val_binary_accuracy: 0.5088 - val_loss: 0.6917
# Epoch 16/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - binary_accuracy: 0.5202 - loss: 0.6932
# Epoch 16: val_loss did not improve from 0.69140
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 642ms/step - binary_accuracy: 0.5150 - loss: 0.6945 - val_binary_accuracy: 0.5097 - val_loss: 0.6964
# Epoch 17/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5095 - loss: 0.6982
# Epoch 17: val_loss did not improve from 0.69140
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 644ms/step - binary_accuracy: 0.5116 - loss: 0.6985 - val_binary_accuracy: 0.4921 - val_loss: 0.6958
# Epoch 18/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - binary_accuracy: 0.4564 - loss: 0.7024
# Epoch 18: val_loss did not improve from 0.69140
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 647ms/step - binary_accuracy: 0.4716 - loss: 0.6991 - val_binary_accuracy: 0.5101 - val_loss: 0.6927
# Epoch 19/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5388 - loss: 0.6893
# Epoch 19: val_loss did not improve from 0.69140
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 644ms/step - binary_accuracy: 0.5200 - loss: 0.6931 - val_binary_accuracy: 0.4934 - val_loss: 0.7001
# Epoch 20/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5103 - loss: 0.6937
# Epoch 20: val_loss did not improve from 0.69140
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 645ms/step - binary_accuracy: 0.5059 - loss: 0.6949 - val_binary_accuracy: 0.5079 - val_loss: 0.7026
# Epoch 21/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - binary_accuracy: 0.4863 - loss: 0.7050
# Epoch 21: val_loss did not improve from 0.69140
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 644ms/step - binary_accuracy: 0.5153 - loss: 0.6971 - val_binary_accuracy: 0.4921 - val_loss: 0.7227
# Fold 1 Best Val Accuracy: 0.5233
# Epoch 1/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - binary_accuracy: 0.5177 - loss: 0.7589
# Epoch 1: val_loss improved from None to 0.69193, saving model to best.weights.h5
#
# Epoch 1: finished saving model to best.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 88s 676ms/step - binary_accuracy: 0.5144 - loss: 0.7228 - val_binary_accuracy: 0.5119 - val_loss: 0.6919
# Epoch 2/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - binary_accuracy: 0.4987 - loss: 0.7078
# Epoch 2: val_loss did not improve from 0.69193
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 642ms/step - binary_accuracy: 0.4981 - loss: 0.7124 - val_binary_accuracy: 0.4912 - val_loss: 0.7088
# Epoch 3/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - binary_accuracy: 0.4953 - loss: 0.7095
# Epoch 3: val_loss did not improve from 0.69193
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 640ms/step - binary_accuracy: 0.5028 - loss: 0.7047 - val_binary_accuracy: 0.4912 - val_loss: 0.7088
# Epoch 4/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - binary_accuracy: 0.5157 - loss: 0.6948
# Epoch 4: val_loss did not improve from 0.69193
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 645ms/step - binary_accuracy: 0.5084 - loss: 0.6998 - val_binary_accuracy: 0.5088 - val_loss: 0.6969
# Epoch 5/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - binary_accuracy: 0.4926 - loss: 0.7164
# Epoch 5: val_loss did not improve from 0.69193
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 640ms/step - binary_accuracy: 0.4928 - loss: 0.7088 - val_binary_accuracy: 0.5150 - val_loss: 0.6923
# Epoch 6/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - binary_accuracy: 0.5083 - loss: 0.6984
# Epoch 6: val_loss did not improve from 0.69193
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 641ms/step - binary_accuracy: 0.4972 - loss: 0.6974 - val_binary_accuracy: 0.5136 - val_loss: 0.6948
# Epoch 7/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.4988 - loss: 0.7023
# Epoch 7: val_loss did not improve from 0.69193
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 643ms/step - binary_accuracy: 0.5091 - loss: 0.7009 - val_binary_accuracy: 0.5189 - val_loss: 0.6967
# Epoch 8/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.4984 - loss: 0.6945
# Epoch 8: val_loss did not improve from 0.69193
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 644ms/step - binary_accuracy: 0.4947 - loss: 0.6963 - val_binary_accuracy: 0.5088 - val_loss: 0.6927
# Epoch 9/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - binary_accuracy: 0.5048 - loss: 0.6965
# Epoch 9: val_loss did not improve from 0.69193
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 642ms/step - binary_accuracy: 0.5066 - loss: 0.6960 - val_binary_accuracy: 0.5198 - val_loss: 0.6923
# Epoch 10/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - binary_accuracy: 0.5177 - loss: 0.6950
# Epoch 10: val_loss did not improve from 0.69193
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 642ms/step - binary_accuracy: 0.5178 - loss: 0.6963 - val_binary_accuracy: 0.5128 - val_loss: 0.6923
# Epoch 11/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - binary_accuracy: 0.5034 - loss: 0.6972
# Epoch 11: val_loss did not improve from 0.69193
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 645ms/step - binary_accuracy: 0.5088 - loss: 0.6963 - val_binary_accuracy: 0.5123 - val_loss: 0.6929
# Epoch 12/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - binary_accuracy: 0.5006 - loss: 0.7025
# Epoch 12: val_loss did not improve from 0.69193
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 643ms/step - binary_accuracy: 0.5003 - loss: 0.7007 - val_binary_accuracy: 0.5079 - val_loss: 0.6926
# Epoch 13/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - binary_accuracy: 0.4900 - loss: 0.6995
# Epoch 13: val_loss did not improve from 0.69193
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 646ms/step - binary_accuracy: 0.4953 - loss: 0.7015 - val_binary_accuracy: 0.5075 - val_loss: 0.6935
# Epoch 14/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5135 - loss: 0.6967
# Epoch 14: val_loss did not improve from 0.69193
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 644ms/step - binary_accuracy: 0.5144 - loss: 0.6988 - val_binary_accuracy: 0.5088 - val_loss: 0.7296
# Epoch 15/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - binary_accuracy: 0.4992 - loss: 0.7082
# Epoch 15: val_loss did not improve from 0.69193
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 646ms/step - binary_accuracy: 0.4953 - loss: 0.7024 - val_binary_accuracy: 0.5150 - val_loss: 0.6923
# Epoch 16/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5423 - loss: 0.6905
# Epoch 16: val_loss did not improve from 0.69193
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 644ms/step - binary_accuracy: 0.5288 - loss: 0.6926 - val_binary_accuracy: 0.5088 - val_loss: 0.7068
# Fold 2 Best Val Accuracy: 0.5119
# Epoch 1/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - binary_accuracy: 0.4915 - loss: 0.8132
# Epoch 1: val_loss improved from None to 0.70563, saving model to best.weights.h5
#
# Epoch 1: finished saving model to best.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 89s 678ms/step - binary_accuracy: 0.5016 - loss: 0.7365 - val_binary_accuracy: 0.5211 - val_loss: 0.7056
# Epoch 2/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - binary_accuracy: 0.5105 - loss: 0.7165
# Epoch 2: val_loss did not improve from 0.70563
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 643ms/step - binary_accuracy: 0.5097 - loss: 0.7170 - val_binary_accuracy: 0.4789 - val_loss: 0.7329
# Epoch 3/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.4863 - loss: 0.7038
# Epoch 3: val_loss improved from 0.70563 to 0.70513, saving model to best.weights.h5
#
# Epoch 3: finished saving model to best.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 648ms/step - binary_accuracy: 0.4997 - loss: 0.6990 - val_binary_accuracy: 0.4789 - val_loss: 0.7051
# Epoch 4/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - binary_accuracy: 0.5165 - loss: 0.6938
# Epoch 4: val_loss improved from 0.70513 to 0.69718, saving model to best.weights.h5
#
# Epoch 4: finished saving model to best.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 648ms/step - binary_accuracy: 0.5256 - loss: 0.6962 - val_binary_accuracy: 0.5189 - val_loss: 0.6972
# Epoch 5/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - binary_accuracy: 0.5127 - loss: 0.6998
# Epoch 5: val_loss improved from 0.69718 to 0.69124, saving model to best.weights.h5
#
# Epoch 5: finished saving model to best.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 649ms/step - binary_accuracy: 0.5109 - loss: 0.6991 - val_binary_accuracy: 0.5260 - val_loss: 0.6912
# Epoch 6/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.4936 - loss: 0.7005
# Epoch 6: val_loss did not improve from 0.69124
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 644ms/step - binary_accuracy: 0.4963 - loss: 0.6995 - val_binary_accuracy: 0.5202 - val_loss: 0.6926
# Epoch 7/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - binary_accuracy: 0.5051 - loss: 0.7072
# Epoch 7: val_loss did not improve from 0.69124
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 642ms/step - binary_accuracy: 0.5141 - loss: 0.7023 - val_binary_accuracy: 0.4789 - val_loss: 0.7067
# Epoch 8/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - binary_accuracy: 0.5068 - loss: 0.7014
# Epoch 8: val_loss did not improve from 0.69124
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 648ms/step - binary_accuracy: 0.5072 - loss: 0.6971 - val_binary_accuracy: 0.5211 - val_loss: 0.7020
# Epoch 9/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - binary_accuracy: 0.5129 - loss: 0.6991
# Epoch 9: val_loss did not improve from 0.69124
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 643ms/step - binary_accuracy: 0.5197 - loss: 0.6965 - val_binary_accuracy: 0.4789 - val_loss: 0.7106
# Epoch 10/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - binary_accuracy: 0.5085 - loss: 0.6958
# Epoch 10: val_loss did not improve from 0.69124
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 647ms/step - binary_accuracy: 0.5197 - loss: 0.6942 - val_binary_accuracy: 0.5211 - val_loss: 0.6990
# Epoch 11/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - binary_accuracy: 0.5124 - loss: 0.6967
# Epoch 11: val_loss did not improve from 0.69124
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 645ms/step - binary_accuracy: 0.5113 - loss: 0.6979 - val_binary_accuracy: 0.4802 - val_loss: 0.7026
# Epoch 12/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - binary_accuracy: 0.5050 - loss: 0.7024
# Epoch 12: val_loss did not improve from 0.69124
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 646ms/step - binary_accuracy: 0.5119 - loss: 0.6988 - val_binary_accuracy: 0.4806 - val_loss: 0.7074
# Epoch 13/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - binary_accuracy: 0.5035 - loss: 0.6957
# Epoch 13: val_loss did not improve from 0.69124
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 644ms/step - binary_accuracy: 0.5094 - loss: 0.6958 - val_binary_accuracy: 0.4793 - val_loss: 0.6963
# Epoch 14/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5049 - loss: 0.6976
# Epoch 14: val_loss did not improve from 0.69124
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 643ms/step - binary_accuracy: 0.5022 - loss: 0.7011 - val_binary_accuracy: 0.5343 - val_loss: 0.6924
# Epoch 15/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - binary_accuracy: 0.5085 - loss: 0.6959
# Epoch 15: val_loss did not improve from 0.69124
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 645ms/step - binary_accuracy: 0.5116 - loss: 0.6980 - val_binary_accuracy: 0.4793 - val_loss: 0.7061
# Epoch 16/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5353 - loss: 0.6927
# Epoch 16: val_loss did not improve from 0.69124
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 643ms/step - binary_accuracy: 0.5297 - loss: 0.6915 - val_binary_accuracy: 0.5321 - val_loss: 0.6924
# Epoch 17/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - binary_accuracy: 0.4889 - loss: 0.6975
# Epoch 17: val_loss did not improve from 0.69124
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 647ms/step - binary_accuracy: 0.4997 - loss: 0.6966 - val_binary_accuracy: 0.5286 - val_loss: 0.6921
# Epoch 18/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - binary_accuracy: 0.5059 - loss: 0.6928
# Epoch 18: val_loss did not improve from 0.69124
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 645ms/step - binary_accuracy: 0.5072 - loss: 0.6934 - val_binary_accuracy: 0.5379 - val_loss: 0.6913
# Epoch 19/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5243 - loss: 0.6940
# Epoch 19: val_loss did not improve from 0.69124
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 645ms/step - binary_accuracy: 0.5166 - loss: 0.6964 - val_binary_accuracy: 0.4789 - val_loss: 0.6995
# Epoch 20/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - binary_accuracy: 0.5017 - loss: 0.6944
# Epoch 20: val_loss did not improve from 0.69124
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 642ms/step - binary_accuracy: 0.5069 - loss: 0.6934 - val_binary_accuracy: 0.5211 - val_loss: 0.6930
# Fold 3 Best Val Accuracy: 0.5260
# Epoch 1/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - binary_accuracy: 0.5235 - loss: 0.7641
# Epoch 1: val_loss improved from None to 0.69526, saving model to best.weights.h5
#
# Epoch 1: finished saving model to best.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 89s 680ms/step - binary_accuracy: 0.5141 - loss: 0.7266 - val_binary_accuracy: 0.4811 - val_loss: 0.6953
# Epoch 2/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - binary_accuracy: 0.4856 - loss: 0.7011
# Epoch 2: val_loss did not improve from 0.69526
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 642ms/step - binary_accuracy: 0.4969 - loss: 0.7024 - val_binary_accuracy: 0.4815 - val_loss: 0.6958
# Epoch 3/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - binary_accuracy: 0.4965 - loss: 0.6994
# Epoch 3: val_loss did not improve from 0.69526
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 641ms/step - binary_accuracy: 0.5000 - loss: 0.7040 - val_binary_accuracy: 0.5238 - val_loss: 0.6995
# Epoch 4/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - binary_accuracy: 0.5109 - loss: 0.7107
# Epoch 4: val_loss did not improve from 0.69526
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 647ms/step - binary_accuracy: 0.5159 - loss: 0.7079 - val_binary_accuracy: 0.5238 - val_loss: 0.7002
# Epoch 5/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - binary_accuracy: 0.5117 - loss: 0.7070
# Epoch 5: val_loss improved from 0.69526 to 0.69087, saving model to best.weights.h5
#
# Epoch 5: finished saving model to best.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 648ms/step - binary_accuracy: 0.5194 - loss: 0.7083 - val_binary_accuracy: 0.5282 - val_loss: 0.6909
# Epoch 6/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - binary_accuracy: 0.4789 - loss: 0.6983
# Epoch 6: val_loss did not improve from 0.69087
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 641ms/step - binary_accuracy: 0.4884 - loss: 0.6979 - val_binary_accuracy: 0.5238 - val_loss: 0.6959
# Epoch 7/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - binary_accuracy: 0.5246 - loss: 0.6976
# Epoch 7: val_loss improved from 0.69087 to 0.69082, saving model to best.weights.h5
#
# Epoch 7: finished saving model to best.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 647ms/step - binary_accuracy: 0.5069 - loss: 0.7060 - val_binary_accuracy: 0.5290 - val_loss: 0.6908
# Epoch 8/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - binary_accuracy: 0.4955 - loss: 0.7091
# Epoch 8: val_loss did not improve from 0.69082
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 644ms/step - binary_accuracy: 0.5009 - loss: 0.7089 - val_binary_accuracy: 0.5238 - val_loss: 0.6920
# Epoch 9/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - binary_accuracy: 0.4819 - loss: 0.7002
# Epoch 9: val_loss did not improve from 0.69082
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 641ms/step - binary_accuracy: 0.4984 - loss: 0.6978 - val_binary_accuracy: 0.4806 - val_loss: 0.6988
# Epoch 10/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - binary_accuracy: 0.5068 - loss: 0.6953
# Epoch 10: val_loss did not improve from 0.69082
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 645ms/step - binary_accuracy: 0.5078 - loss: 0.6968 - val_binary_accuracy: 0.4820 - val_loss: 0.6988
# Epoch 11/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - binary_accuracy: 0.5059 - loss: 0.7013
# Epoch 11: val_loss did not improve from 0.69082
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 645ms/step - binary_accuracy: 0.5166 - loss: 0.7002 - val_binary_accuracy: 0.4762 - val_loss: 0.6987
# Epoch 12/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - binary_accuracy: 0.5063 - loss: 0.6984
# Epoch 12: val_loss improved from 0.69082 to 0.68930, saving model to best.weights.h5
#
# Epoch 12: finished saving model to best.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 648ms/step - binary_accuracy: 0.5100 - loss: 0.6964 - val_binary_accuracy: 0.5352 - val_loss: 0.6893
# Epoch 13/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5057 - loss: 0.6963
# Epoch 13: val_loss did not improve from 0.68930
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 644ms/step - binary_accuracy: 0.5106 - loss: 0.6971 - val_binary_accuracy: 0.4824 - val_loss: 0.6944
# Epoch 14/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - binary_accuracy: 0.4880 - loss: 0.6970
# Epoch 14: val_loss did not improve from 0.68930
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 645ms/step - binary_accuracy: 0.4953 - loss: 0.6985 - val_binary_accuracy: 0.5335 - val_loss: 0.6909
# Epoch 15/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - binary_accuracy: 0.5081 - loss: 0.6951
# Epoch 15: val_loss did not improve from 0.68930
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 641ms/step - binary_accuracy: 0.5178 - loss: 0.6937 - val_binary_accuracy: 0.4815 - val_loss: 0.7036
# Epoch 16/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.4911 - loss: 0.6972
# Epoch 16: val_loss did not improve from 0.68930
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 644ms/step - binary_accuracy: 0.5075 - loss: 0.6953 - val_binary_accuracy: 0.4815 - val_loss: 0.6945
# Epoch 17/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.4848 - loss: 0.7037
# Epoch 17: val_loss did not improve from 0.68930
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 645ms/step - binary_accuracy: 0.5031 - loss: 0.7009 - val_binary_accuracy: 0.5335 - val_loss: 0.6903
# Epoch 18/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.4947 - loss: 0.6950
# Epoch 18: val_loss did not improve from 0.68930
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 644ms/step - binary_accuracy: 0.4966 - loss: 0.6956 - val_binary_accuracy: 0.5401 - val_loss: 0.6913
# Epoch 19/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - binary_accuracy: 0.5301 - loss: 0.6931
# Epoch 19: val_loss did not improve from 0.68930
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 642ms/step - binary_accuracy: 0.5259 - loss: 0.6945 - val_binary_accuracy: 0.4771 - val_loss: 0.7014
# Epoch 20/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - binary_accuracy: 0.4660 - loss: 0.7010
# Epoch 20: val_loss did not improve from 0.68930
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 645ms/step - binary_accuracy: 0.4791 - loss: 0.6976 - val_binary_accuracy: 0.5387 - val_loss: 0.6899
# Epoch 21/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - binary_accuracy: 0.5255 - loss: 0.6941
# Epoch 21: val_loss did not improve from 0.68930
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 646ms/step - binary_accuracy: 0.5263 - loss: 0.6945 - val_binary_accuracy: 0.5238 - val_loss: 0.6941
# Epoch 22/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5376 - loss: 0.6888
# Epoch 22: val_loss did not improve from 0.68930
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 644ms/step - binary_accuracy: 0.5122 - loss: 0.6949 - val_binary_accuracy: 0.5238 - val_loss: 0.6909
# Epoch 23/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - binary_accuracy: 0.4988 - loss: 0.6953
# Epoch 23: val_loss did not improve from 0.68930
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 644ms/step - binary_accuracy: 0.4956 - loss: 0.6954 - val_binary_accuracy: 0.4811 - val_loss: 0.6968
# Epoch 24/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5159 - loss: 0.6966
# Epoch 24: val_loss did not improve from 0.68930
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 644ms/step - binary_accuracy: 0.5106 - loss: 0.6978 - val_binary_accuracy: 0.5238 - val_loss: 0.7143
# Epoch 25/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5127 - loss: 0.7024
# Epoch 25: val_loss did not improve from 0.68930
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 645ms/step - binary_accuracy: 0.5166 - loss: 0.6973 - val_binary_accuracy: 0.4991 - val_loss: 0.6930
# Epoch 26/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - binary_accuracy: 0.5084 - loss: 0.6945
# Epoch 26: val_loss did not improve from 0.68930
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 646ms/step - binary_accuracy: 0.5159 - loss: 0.6966 - val_binary_accuracy: 0.4815 - val_loss: 0.7000
# Epoch 27/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - binary_accuracy: 0.5232 - loss: 0.6933
# Epoch 27: val_loss did not improve from 0.68930
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 645ms/step - binary_accuracy: 0.5175 - loss: 0.6958 - val_binary_accuracy: 0.5238 - val_loss: 0.6989
# Fold 4 Best Val Accuracy: 0.5352
#
# ========================================
#       最终交叉验证报告 (CV REPORT)
# ========================================
# Fold 0: 准确率 = 0.5238
# Fold 1: 准确率 = 0.5233
# Fold 2: 准确率 = 0.5119
# Fold 3: 准确率 = 0.5260
# Fold 4: 准确率 = 0.5352
# ----------------------------------------
# 平均准确率 (Mean): 0.5240
# 标准差 (Std Dev):  0.0074
# 综合表现: 0.5240 ± 0.0074
# ========================================

# %%
#flight_res

# %%
#print(flight_res)

# %% [markdown]
# <a href="https://colab.research.google.com/github/hyang0129/NGAFIDDATASET/blob/main/NGAFID_DATASET_DASK_EXAMPLE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INSTALL PREREQ

# %%
# !python -m pip install "dask[dataframe]"
# Out:
# Requirement already satisfied: dask[dataframe] in /usr/local/lib/python3.12/dist-packages (2026.1.2)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]) (8.3.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]) (2025.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]) (26.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]) (6.0.3)
# Requirement already satisfied: toolz>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]) (0.12.1)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]) (2.2.2)
# Requirement already satisfied: pyarrow>=16.0 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]) (18.1.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->dask[dataframe]) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->dask[dataframe]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->dask[dataframe]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->dask[dataframe]) (2025.3)
# Requirement already satisfied: locket in /usr/local/lib/python3.12/dist-packages (from partd>=1.4.0->dask[dataframe]) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0->dask[dataframe]) (1.17.0)

# %%
# !git clone https://github.com/ccDT2022/NGAFIDDATASET.git

!(cd NGAFIDDATASET ; git checkout main; git reset --hard HEAD; git pull)
!(cd NGAFIDDATASET ; pip install -r requirements.txt -q)
# Out:
# fatal: destination path 'NGAFIDDATASET' already exists and is not an empty directory.
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# HEAD is now at 086bc38 Add files via upload
# Already up to date.

# %% [markdown]
# # IMPORT DEPENDENCIES

# %%
# 1. 导入必要的系统库
import sys
import importlib

# 2. 打补丁：将 importlib 伪装成 Python 3.12 中已经被移除的 imp 模块
sys.modules['imp'] = importlib

# 3. 补充原代码逻辑：将下载好的数据集项目路径添加到系统环境变量中
sys.path.append('/content/NGAFIDDATASET')

# 4. 此时系统里已经有了一个“假”的 imp，可以安全地加载 autoreload 扩展了
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# 1. 删除刚才下载错的“伪装成压缩包的网页”
# !rm -f /content/all_flights.tar.gz

# 2. 使用正确的直接下载链接（利用 Google Drive 的 uc?id 接口）强制下载真正的数据
# !gdown "https://drive.google.com/uc?id=1KN9DQJX63D-0QbKEish9g1n4aF51mIwb" -O /content/all_flights.tar.gz

# 3. 手动解压缩真正的数据集到当前目录
# !tar -xzf /content/all_flights.tar.gz -C /content/
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1KN9DQJX63D-0QbKEish9g1n4aF51mIwb
# From (redirected): https://drive.google.com/uc?id=1KN9DQJX63D-0QbKEish9g1n4aF51mIwb&confirm=t&uuid=e0bddec0-69f9-42c9-b60d-ecf04b4083ee
# To: /content/all_flights.tar.gz
# 100% 4.29G/4.29G [00:47<00:00, 91.2MB/s]

# %%
import dask.dataframe as dd

flight_data_df = dd.read_parquet('all_flights/one_parq')

flight_header_df = pd.read_csv('/content/all_flights/flight_header.csv', index_col = 'Master Index')

# %%
flight_data_df
# Out:
# Dask DataFrame Structure:
#                    volt1    volt2     amp1     amp2    FQtyL    FQtyR E1 FFlow  E1 OilT  E1 OilP   E1 RPM  E1 CHT1  E1 CHT2  E1 CHT3  E1 CHT4  E1 EGT1  E1 EGT2  E1 EGT3  E1 EGT4      OAT      IAS     VSpd   NormAc   AltMSL timestep cluster
# npartitions=401
#                  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64    int64  string
#                      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...     ...
# ...                  ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...     ...
#                      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...     ...
#                      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...     ...
# Dask Name: read_parquet, 1 expression
# Expr=ReadParquetFSSpec(5b6e683)

# %%
flight_data_df.head(5)
# Out:
#               volt1  volt2  amp1  amp2  FQtyL  FQtyR  E1 FFlow  E1 OilT  \
# Master Index
# 1              28.8    NaN   0.8   NaN  48.89  44.06     13.28   168.55
# 1              28.8    NaN   0.8   NaN  48.93  44.06     13.31   168.60
# 1              28.8    NaN   0.9   NaN  48.96  44.06     13.36   168.65
# 1              28.8    NaN   0.7   NaN  48.86  44.06     13.30   168.64
# 1              28.8    NaN   0.6   NaN  48.87  44.06     13.30   168.65
#
#               E1 OilP  E1 RPM  ...  E1 EGT2  E1 EGT3  E1 EGT4   OAT     IAS  \
# Master Index                   ...
# 1               82.51  2519.7  ...  1317.44  1298.97  1322.83  12.8  144.89
# 1               82.51  2519.4  ...  1316.64  1300.68  1322.15  12.8  144.53
# 1               82.51  2520.3  ...  1317.20  1301.05  1323.12  12.8  144.15
# 1               82.51  2519.3  ...  1317.73  1302.14  1321.93  12.8  143.79
# 1               82.51  2518.8  ...  1318.00  1308.52  1316.99  12.8  143.45
#
#                VSpd  NormAc  AltMSL  timestep  cluster
# Master Index
# 1             29.61    0.01  3010.7      3151     c_28
# 1             49.78   -0.00  3011.3      3150     c_28
# 1             58.68   -0.01  3011.8      3149     c_28
# 1             47.31   -0.00  3012.2      3148     c_28
# 1             36.05   -0.01  3012.3      3147     c_28
#
# [5 rows x 25 columns]

# %%
flight_header_df.head(5)
# Out:
#              before_after  date_diff  flight_length  \
# Master Index
# 1                  before         -1         4723.0
# 2                  before         -2         4649.0
# 3                    same          0           40.0
# 4                  before          0           14.0
# 5                    same          0          683.0
#
#                                   label hierarchy  number_flights_before
# Master Index
# 1             intake gasket leak/damage       NaN                      0
# 2             intake gasket leak/damage       NaN                      3
# 3             intake gasket leak/damage       NaN                     -1
# 4             intake gasket leak/damage       NaN                      0
# 5             intake gasket leak/damage       NaN                     -1
